# %% [markdown]
# <a href="https://colab.research.google.com/github/manojabacholla/week-1/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,Python!")
if True:
     print("This is indented correctly.")
else:
     print("This won't run.")
name = "Alice"
age = 25
height = 5.4
print("Name:", name)
print("Age:", age)
print("Height:", height)
name= 129
print("newname=",name)
a=12
print(type(a))
b=2.3
print(type(b))
c="praisy"
print(type(c))
d= True
print(type(d))
e=[1,2,3,"four"]
print(type(e),e)
f={"name":"praisy","age":18}
print(type(f),f)
print("Welcome to Python I/O!")
user_name = input("Enter your name: ")
print("Hello,", user_name)
user_age=int(input("enter your age"))
print("you will be of age next year",user_age+1)
# Out:
# Hello,Python!
# This is indented correctly.
# Name: Alice
# Age: 25
# Height: 5.4
# newname= 129
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'praisy', 'age': 18}
# Welcome to Python I/O!
# Enter your name: praisy
# Hello, praisy
# enter your age18
# you will be of age next year 19
